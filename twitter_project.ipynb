# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.graph_objects as go

import plotly.express as px

import plotly.io as pio

# %%
# !pip install --upgrade plotly
# Out:
# ...
#    ---------------------------------------- 0.0/19.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.0 MB 330.3 kB/s eta 0:00:58
#    ---------------------------------------- 0.0/19.0 MB 393.8 kB/s eta 0:00:49
#    ---------------------------------------- 0.1/19.0 MB 655.4 kB/s eta 0:00:29
#     --------------------------------------- 0.5/19.0 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.2/19.0 MB 5.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.3/19.0 MB 8.5 MB/s eta 0:00:02
#    --------- ------------------------------ 4.7/19.0 MB 14.4 MB/s eta 0:00:01
#    ------------- -------------------------- 6.4/19.0 MB 17.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 8.4/19.0 MB 19.8 MB/s eta 0:00:01
#    --------------------- ------------------ 10.3/19.0 MB 26.2 MB/s eta 0:00:01
# ...

# %%
# !pip install plotly

# %%
df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")

print(df.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1 2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2 2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3 2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4 2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
#Read the data and display the first 100 rows from the data

# %%
df.head(100)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
# ..        ...        ...        ...        ...        ...        ...
# 95 2014-03-27  45.090000  46.400002  43.310001  46.320000  46.320000
# 96 2014-03-28  46.650002  47.340000  45.700001  47.299999  47.299999
# 97 2014-03-31  47.549999  47.750000  46.430000  46.669998  46.669998
# 98 2014-04-01  46.709999  47.590000  46.180000  46.980000  46.980000
# 99 2014-04-02  47.400002  47.439999  45.509998  45.730000  45.730000
#
#          Volume
# 0   117701670.0
# 1    27925307.0
# 2    16113941.0
# 3     6316755.0
# 4     8688325.0
# ..          ...
# ...

# %%
# Give the column insights 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2264 non-null   datetime64[ns]
#  1   Open       2259 non-null   float64
#  2   High       2259 non-null   float64
#  3   Low        2259 non-null   float64
#  4   Close      2259 non-null   float64
#  5   Adj Close  2259 non-null   float64
#  6   Volume     2259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 123.9 KB

# %%
# Check whether this dataset contains any null values or not if it is there then remove the null values from it
df.isnull().sum()
# Out:
# Date         0
# Open         5
# High         5
# Low          5
# Close        5
# Adj Close    5
# Volume       5
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Find the statistical description of the data
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2264  2259.000000  2259.000000  2259.000000
# mean   2018-05-08 11:16:44.946996480    36.020286    36.699881    35.339465
# min              2013-11-07 00:00:00    13.950000    14.220000    13.725000
# 25%              2016-02-08 18:00:00    25.550000    26.215001    24.912501
# 50%              2018-05-08 12:00:00    35.419998    36.099998    34.820000
# 75%              2020-08-06 06:00:00    44.205000    45.015000    43.327501
# max              2022-11-03 00:00:00    78.360001    80.750000    76.050003
# std                              NaN    14.118463    14.372057    13.828724
#
#              Close    Adj Close        Volume
# count  2259.000000  2259.000000  2.259000e+03
# mean     36.003625    36.003625  2.175186e+07
# min      14.010000    14.010000  0.000000e+00
# 25%      25.410000    25.410000  1.233530e+07
# 50%      35.490002    35.490002  1.691305e+07
# ...

# %%
# Find the missing values in the data 
df.duplicated().sum()
# Out:
# 0

# %%
# !pip install statistics
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7450 sha256=0a26ec5e5969d1d20cc8795c005bd2515dbe81050e18c777b806dafec329f278
#   Stored in directory: c:\users\chand\appdata\local\pip\cache\wheels\a7\30\34\fceae1c718a4e749dd51f479c5720c0671519887e824915e90
# Successfully built statistics
# ...

# %%
# !pip install dash jupyter-dash pandas plotly wordcloud matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.5 MB 2.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.4/7.5 MB 4.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.5 MB 9.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.0/7.5 MB 17.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.4/7.5 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.5/7.5 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 24.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 21.7 MB/s eta 0:00:00
# ...

# %%
# !pip install numpy

# %%
# !pip install scipy

# %%
#Give me the Z-test O/R T-test over High, low, and close columns and see if the null hypothesis gets rejected or accepted

import pandas as pd
from statsmodels.stats import weightstats as stests
from scipy import stats

df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")

test_value = 30
alpha = 0.05

def perform_ztest(column, test_value):
    ztest, pval = stests.ztest(column, value=test_value)
    return ztest, pval

def perform_ttest(column, test_value):
    ttest_statistic, pval = stats.ttest_1samp(column, test_value)
    return ttest_statistic, pval

def print_results(test_name, column_name, test_statistic, pval):
    print(f"{test_name} for column '{column_name}':")
    print(f"  Test Statistic: {test_statistic}")
    print(f"  P-Value: {pval}")
    if pval < alpha:
        print("  Reject the null hypothesis")
    else:
        print("  Accept the null hypothesis")
    print()

specific_columns = ['High', 'Low', 'Close']
  
for column_name in specific_columns:
    column = df[column_name].dropna()  


    
    # Perform Z-test
    ztest_statistic, ztest_pval = perform_ztest(column, test_value)
    print_results("Z-Test", column_name, ztest_statistic, ztest_pval)
    
    # Perform T-test
    ttest_statistic, ttest_pval = perform_ttest(column, test_value)
    print_results("T-Test", column_name, ttest_statistic, ttest_pval)
# Out:
# Z-Test for column 'High':
#   Test Statistic: 22.15676048174423
#   P-Value: 8.978177265940086e-109
#   Reject the null hypothesis
#
# T-Test for column 'High':
#   Test Statistic: 22.15676048174423
#   P-Value: 1.3745989635531811e-98
#   Reject the null hypothesis
#
# Z-Test for column 'Low':
#   Test Statistic: 18.35159210972168
#   P-Value: 3.205795428365976e-75
#   Reject the null hypothesis
#
# T-Test for column 'Low':
#   Test Statistic: 18.351592109721675
#   P-Value: 3.1751565105922235e-70
#   Reject the null hypothesis
#
# Z-Test for column 'Close':
#   Test Statistic: 20.251679995652125
#   P-Value: 3.433291673809823e-91
#   Reject the null hypothesis
#
# T-Test for column 'Close':
#   Test Statistic: 20.251679995652125
#   P-Value: 6.26844020254432e-84
#   Reject the null hypothesis

# %%
#Check if the data is dependent or independent by using the chi-square method

df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")

# Creating  categorical columns from continuous data

# Example 1: Categorize 'Close' prices into 'Low', 'Medium', 'High'
close_bins = [0, 40, 45, float('inf')]  # Define bins based on your data
close_labels = ['Low', 'Medium', 'High']
df['Close_Category'] = pd.cut(df['Close'], bins=close_bins, labels=close_labels)

# Example 2: Binarize 'Volume' into 'High Volume' or 'Low Volume'
volume_median = df['Volume'].median()
df['Volume_Category'] = df['Volume'].apply(lambda x: 'High Volume' if x > volume_median else 'Low Volume')

# Create a contingency table
contingency_table = pd.crosstab(df['Close_Category'], df['Volume_Category'])

# Perform Chi-square test of independence
chi2_stat, p_val, dof, expected = stats.chi2_contingency(contingency_table)

# Print results
print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_val}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies Table:\n{expected}")

# Interpret the result
alpha = 0.05
if p_val < alpha:
    print("Reject the null hypothesis: The variables are dependent.")
else:
    print("Accept the null hypothesis: The variables are independent.")
# Out:
# Chi-Square Statistic: 33.680800974006516
# P-Value: 4.856316637022679e-08
# Degrees of Freedom: 2
# Expected Frequencies Table:
# [[737.67330677 738.32669323]
#  [127.4435591  127.5564409 ]
#  [263.88313413 264.11686587]]
# Reject the null hypothesis: The variables are dependent.

# %%
#Show the Twitter stock prices over the years and give a conclusion
df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")
figure = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'],
    increasing=dict(line=dict(color='green'), fillcolor='lightgreen'),  
    decreasing=dict(line=dict(color='red'), fillcolor='lightcoral')   

)])


figure.update_layout(
    title='Twitter stock prices over the years',
    yaxis_title='Stock Price',
    xaxis_title='Date',
    xaxis_rangeslider_visible=True)


figure.show()
# Out:
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
#Now compare the close vs date column for Twitter prices over the years.

df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")

figure = go.Figure(data=[go.Scatter(
    x=df['Date'],               
    y=df['Close'],
     mode='lines',              
    line=dict(color='red'),    
    name='Close Price'  
          
)])


figure.update_layout(
    title='Twitter Closing Prices Over the Years',
    xaxis_title='Date',
    yaxis_title='Close Price',
    xaxis_rangeslider_visible=True 
)

figure.show()
# Out:
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
#Assign buttons to control time periods. Add the 
#buttons to analyze the stock prices of Twitter in different time periods:

figure = px.bar(df, x='Date', y='High', color='Close')

figure.update_layout(
    title='Comparison of Close Vs Date Columns',
    # yaxis_title='Stock Price',
    # xaxis_title='Date',
)

figure.update_xaxes(
   rangeselector = dict(

                    buttons = list([

                                dict(count=1, label="1m", step="month" ),
                                dict(count=6, label="6m", step="month"),
                                dict(count=1, label="YTD", step="year"),
                                dict(count=1, label="1y", step="year"),
                                dict(count = 3, label = "3y", step = "year"),
                                dict(step="all")  ])
   )
)

figure.show()
# Out:
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
#Give the complete timeline of Twitter in the stock market. (Line Graph)

date = df['Date'].dt.year
x = date
y = df['Close']

figure = px.line(df, x='Date', y='Close')

figure.update_layout(
    title='Twitter stock prices over the years',
    yaxis_title='Stock Price',
    xaxis_title='Date',
    xaxis_rangeslider_visible=True
)


figure.show()
# Out:
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
# !pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------  297.0/300.2 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample insights based on the analysis
insights_text = """
Twitter stock prices show varying trends over time. 
Recent trends indicate periods of high volatility, 
with significant fluctuations observed. 
The long-term trend shows an overall growth, 
with periods of significant highs and lows. 
Comparing close and high prices reveals patterns 
of market reactions and investor sentiment.
"""

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(insights_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Word Cloud of Analysis Insights')
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import io
import base64
from dash import dcc, html
from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output

# Load data
df = pd.read_excel("C:/Users/chand/Downloads/TWTR (2).xlsx")

# Create the Candlestick Chart
candlestick_chart = go.Figure(data=[go.Candlestick(
    x=df['Date'],
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close']
)])
candlestick_chart.update_layout(
    title='Twitter Stock Prices Over the Years',
    yaxis_title='Stock Price',
    xaxis_title='Date',
    xaxis_rangeslider_visible=True
)

# Create the Bar Chart
bar_chart = px.bar(df, x='Date', y='High', color='Close', title='Comparison of Close vs High Prices')
bar_chart.update_layout(
    xaxis_title='Date',
    yaxis_title='Stock Price'
)

# Create Word Cloud
insights_text = """
Twitter stock prices show varying trends over time. 
Recent trends indicate periods of high volatility, 
with significant fluctuations observed. 
The long-term trend shows an overall growth, 
with periods of significant highs and lows. 
Comparing close and high prices reveals patterns 
of market reactions and investor sentiment.
"""
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(insights_text)

# Save the Word Cloud to a BytesIO object
wordcloud_img = io.BytesIO()
wordcloud.to_image().save(wordcloud_img, format='PNG')
wordcloud_img.seek(0)
wordcloud_img_b64 = base64.b64encode(wordcloud_img.getvalue()).decode()

# Initialize the Dash app
app = JupyterDash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("Twitter Stock Analysis Dashboard"),

    html.Div([
        dcc.Graph(figure=candlestick_chart)
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        dcc.Graph(figure=bar_chart)
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        html.H3("Insights"),
        html.Img(src=f'data:image/png;base64,{wordcloud_img_b64}')
    ])
])

# Run the app in Jupyter Notebook
app.run_server(mode='inline')
# Out:
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# C:\Users\chand\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# C:\Users\chand\anaconda3\Lib\site-packages\dash\dash.py:562: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
# ...
